# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
import csv

from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import RFE

print('Read Data')
# Read train file
un_trainX = numpy.genfromtxt("trainFeatures.csv", delimiter=',')
n_trainX = un_trainX / un_trainX.max(axis=0)
trainLabel = numpy.genfromtxt("trainLabel.csv", delimiter=',')
# Read validation file
un_testX = numpy.genfromtxt("validationFeatures.csv", delimiter=',')
n_testX = un_testX / un_trainX.max(axis=0)
testLabel = numpy.genfromtxt("validationLabel.csv", delimiter=',')
# Read test file
un_testdata = numpy.genfromtxt("test.csv", delimiter=',')
n_testdata = un_testdata / un_trainX.max(axis=0)

k = [60, 80, 100, 120, 140]
maX = 0
for i in range(len(k)):
    print("Selecting features = ", k[i])
    selection = SelectKBest(k=k[i]).fit(n_trainX, trainLabel)
    n_trainX_new = selection.transform(n_trainX)
    n_testX_new = selection.transform(n_testX)
    n_testdata_new = selection.transform(n_testdata)

    depth = [40, 80, 100, 150, 200]
    accuracy = []
    for j in range(len(depth)):
        print("Training min_samples_leaf = ", depth[j])
        clf = DecisionTreeClassifier(criterion="gini", min_samples_leaf=depth[j], random_state=0)
        clf.fit(n_trainX_new, trainLabel)
        # compute accuracy
        result = clf.score(n_testX_new, testLabel)
        print("accuracy = ", result)
        accuracy.append(result)
        if (result > maX):
            maX = result
            print("Predict and write to file")
            answer = clf.predict(n_testdata_new)
            numpy.savetxt('result.csv', answer, delimiter=',', fmt='%d')
    
    plt.plot(depth, accuracy)
    plt.show()
# Out:
# Read Data
# Selecting features =  60
# Training min_samples_leaf =  40
# accuracy =  0.7018
# Predict and write to file
# Training min_samples_leaf =  80
# accuracy =  0.705122222222
# Predict and write to file
# Training min_samples_leaf =  100
# accuracy =  0.708366666667
# Predict and write to file
# Training min_samples_leaf =  150
# accuracy =  0.710055555556
# Predict and write to file
# Training min_samples_leaf =  200
# accuracy =  0.705355555556
# Selecting features =  80
# Training min_samples_leaf =  40
# accuracy =  0.704344444444
# Training min_samples_leaf =  80
# accuracy =  0.707522222222
# Training min_samples_leaf =  100
# accuracy =  0.710511111111
# Predict and write to file
# Training min_samples_leaf =  150
# accuracy =  0.710455555556
# Training min_samples_leaf =  200
# accuracy =  0.707411111111
# Selecting features =  100
# Training min_samples_leaf =  40
# accuracy =  0.703522222222
# Training min_samples_leaf =  80
# accuracy =  0.702166666667
# Training min_samples_leaf =  100
# accuracy =  0.704322222222
# Training min_samples_leaf =  150
# accuracy =  0.706844444444
# Training min_samples_leaf =  200
# accuracy =  0.703388888889
# Selecting features =  120
# Training min_samples_leaf =  40
# accuracy =  0.704355555556
# Training min_samples_leaf =  80
# accuracy =  0.704355555556
# Training min_samples_leaf =  100
# accuracy =  0.706255555556
# Training min_samples_leaf =  150
# accuracy =  0.708488888889
# Training min_samples_leaf =  200
# accuracy =  0.704444444444
# Selecting features =  140
# Training min_samples_leaf =  40
# accuracy =  0.702111111111
# Training min_samples_leaf =  80
# accuracy =  0.701833333333
# Training min_samples_leaf =  100
# accuracy =  0.702733333333
# Training min_samples_leaf =  150
# accuracy =  0.7057
# Training min_samples_leaf =  200
# accuracy =  0.697733333333

# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
import csv

from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import RFE

print('Read Data')
# Read train file
un_trainX = numpy.genfromtxt("trainFeatures.csv", delimiter=',')
n_trainX = un_trainX / un_trainX.max(axis=0)
trainLabel = numpy.genfromtxt("trainLabel.csv", delimiter=',')
# Read validation file
un_testX = numpy.genfromtxt("validationFeatures.csv", delimiter=',')
n_testX = un_testX / un_trainX.max(axis=0)
testLabel = numpy.genfromtxt("validationLabel.csv", delimiter=',')
# Read test file
un_testdata = numpy.genfromtxt("test.csv", delimiter=',')
n_testdata = un_testdata / un_trainX.max(axis=0)

k = [140, 120, 100, 80, 60]
maX = 0
for i in range(len(k)):
    depth = [1, 2, 3, 5, 7, 10, 15, 20]
    accuracy = []
    print("Selecting features = ", k[i])
    for j in range(len(depth)):
        estimator = DecisionTreeClassifier(criterion="gini", max_depth=depth[j], random_state=0)
        clf = RFE(estimator, k[i], 5)
        print("Training Maxdepth = ", depth[j])
        clf.fit(n_trainX_new, trainLabel)
        # compute accuracy
        result = clf.score(n_testX_new, testLabel)
        print("accuracy = ", result)
        accuracy.append(result)
        if (result > 0.78 and result > maX):
            maX = result
            print("Predict and write to file")
            answer = clf.predict(n_testdata_new)
            numpy.savetxt('result.csv', result, delimiter=',', fmt='%d')
    
    plt.plot(depth, accuracy)
    plt.show()
# Out:
# Read Data
# Selecting features =  140
# Training Maxdepth =  1
# accuracy =  0.539466666667
# Training Maxdepth =  2
# accuracy =  0.658033333333
# Training Maxdepth =  3
# accuracy =  0.668511111111
# Training Maxdepth =  5
# accuracy =  0.6957
# Training Maxdepth =  7
# accuracy =  0.7094
# Training Maxdepth =  10
# accuracy =  0.711277777778
# Training Maxdepth =  15
# accuracy =  0.706977777778
# Training Maxdepth =  20
# accuracy =  0.696288888889
# Selecting features =  120
# Training Maxdepth =  1
# accuracy =  0.539466666667
# Training Maxdepth =  2
# accuracy =  0.658033333333
# Training Maxdepth =  3
# accuracy =  0.668511111111
# Training Maxdepth =  5
# accuracy =  0.6957
# Training Maxdepth =  7
# accuracy =  0.7094
# Training Maxdepth =  10
# accuracy =  0.711277777778
# Training Maxdepth =  15
# accuracy =  0.706977777778
# Training Maxdepth =  20
# accuracy =  0.696288888889
# Selecting features =  100
# Training Maxdepth =  1
# accuracy =  0.539466666667
# Training Maxdepth =  2
# accuracy =  0.658033333333
# Training Maxdepth =  3
# accuracy =  0.668511111111
# Training Maxdepth =  5
# accuracy =  0.6957
# Training Maxdepth =  7
# accuracy =  0.7094
# Training Maxdepth =  10
# accuracy =  0.711277777778
# Training Maxdepth =  15
# accuracy =  0.706977777778
# Training Maxdepth =  20
# accuracy =  0.696288888889
# Selecting features =  80
# Training Maxdepth =  1
# accuracy =  0.539466666667
# Training Maxdepth =  2
# accuracy =  0.658033333333
# Training Maxdepth =  3
# accuracy =  0.668511111111
# Training Maxdepth =  5
# accuracy =  0.6957
# Training Maxdepth =  7
# accuracy =  0.7094
# Training Maxdepth =  10
# accuracy =  0.711277777778
# Training Maxdepth =  15
# accuracy =  0.706977777778
# Training Maxdepth =  20
# accuracy =  0.696288888889
# Selecting features =  60
# Training Maxdepth =  1
# accuracy =  0.539466666667
# Training Maxdepth =  2
# accuracy =  0.658033333333
# Training Maxdepth =  3
# accuracy =  0.668511111111
# Training Maxdepth =  5
# accuracy =  0.6957
# Training Maxdepth =  7
# accuracy =  0.709344444444
# Training Maxdepth =  10
# accuracy =  0.711155555556
# Training Maxdepth =  15
# accuracy =  0.712177777778
# Training Maxdepth =  20
# accuracy =  0.699811111111
