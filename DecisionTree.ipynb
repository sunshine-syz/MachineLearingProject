# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
import csv

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest

print('Read Data')
# Read train file
un_trainX = numpy.genfromtxt("trainFeatures.csv", delimiter=',')
n_trainX = un_trainX / un_trainX.max(axis=0)
trainLabel = numpy.genfromtxt("trainLabel.csv", delimiter=',')
n_trainX = un_trainX

# Read validation file
un_testX = numpy.genfromtxt("validationFeatures.csv", delimiter=',')
n_testX = un_testX / un_trainX.max(axis=0)
testLabel = numpy.genfromtxt("validationLabel.csv", delimiter=',')
n_testX = un_testX
# Read test file
un_testdata = numpy.genfromtxt("test.csv", delimiter=',')
n_testdata = un_testdata / un_trainX.max(axis=0)
n_testdata = un_testdata


selection = SelectKBest(k=100).fit(n_trainX, trainLabel)
n_trainX_new = selection.transform(n_trainX)
n_testX_new = selection.transform(n_testX)
n_testdata_new = selection.transform(n_testdata)

n = [10, 25, 50, 100]
depth = [1, 3, 5, 10, 20]
k = [90, 100, 110, 120, 130, 140]
accuracy = []
for i in range(len(k)):
    print(k[i], "Features")
    selection = SelectKBest(k=k[i]).fit(n_trainX, trainLabel)
    n_trainX_new = selection.transform(n_trainX)
    n_testX_new = selection.transform(n_testX)
    n_testdata_new = selection.transform(n_testdata)
    accuracy = []
    for j in range(len(depth)):
        print("training.... maxdepth=", depth[j])
        # train depth = 1
        clf = AdaBoostClassifier(base_estimator = DecisionTreeClassifier(max_depth=depth[j]), n_estimators = 20)
        clf.fit(n_trainX_new, trainLabel)
        # compute accuracy
        result = clf.score(n_testX_new, testLabel)
        print("accuracy = ", result)
        accuracy.append(result)
    print("Completed")
#     plt.xlabel('m')
#     plt.ylabel('Accuracy')
#     plt.title('Accuracy vs number of weak classifiers')

#     plt.plot(n, accuracy, '--.')
#     plt.show()
# Out:
# Read Data
# 90 Features
# training.... maxdepth= 1
# accuracy =  0.556211111111
# training.... maxdepth= 3
# accuracy =  0.730544444444
# training.... maxdepth= 5
# accuracy =  0.729566666667
# training.... maxdepth= 10
# accuracy =  0.678344444444
# training.... maxdepth= 20
# accuracy =  0.707766666667
# Completed
# 100 Features
# training.... maxdepth= 1
# accuracy =  0.5531
# training.... maxdepth= 3
# accuracy =  0.734688888889
# training.... maxdepth= 5
# accuracy =  0.739355555556
# training.... maxdepth= 10
# accuracy =  0.676944444444
# training.... maxdepth= 20
# accuracy =  0.707577777778
# Completed
# 110 Features
# training.... maxdepth= 1
# accuracy =  0.551322222222
# training.... maxdepth= 3
# accuracy =  0.723966666667
# training.... maxdepth= 5
# accuracy =  0.734044444444
# training.... maxdepth= 10
# accuracy =  0.677233333333
# training.... maxdepth= 20
# accuracy =  0.701633333333
# Completed
# 120 Features
# training.... maxdepth= 1
# accuracy =  0.551322222222
# training.... maxdepth= 3
# accuracy =  0.727488888889
# training.... maxdepth= 5
# accuracy =  0.730255555556
# training.... maxdepth= 10
# accuracy =  0.679677777778
# training.... maxdepth= 20
# accuracy =  0.699655555556
# Completed
# 130 Features
# training.... maxdepth= 1
# accuracy =  0.556288888889
# training.... maxdepth= 3
# accuracy =  0.732777777778
# training.... maxdepth= 5
# accuracy =  0.732877777778
# training.... maxdepth= 10
# accuracy =  0.673511111111
# training.... maxdepth= 20
# accuracy =  0.692333333333
# Completed
# 140 Features
# training.... maxdepth= 1
# accuracy =  0.556288888889
# training.... maxdepth= 3
# accuracy =  0.734044444444
# training.... maxdepth= 5
# accuracy =  0.733344444444
# training.... maxdepth= 10
# accuracy =  0.670522222222
# training.... maxdepth= 20
# accuracy =  0.696744444444
# Completed
